# %%
# Import the necessary modules
import pandas as pd
import numpy as np
import re
from nltk.tokenize import TweetTokenizer, WhitespaceTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

#training Modules
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

#Evaluation Modules
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix, classification_report

# %%
#reading the dataset files

train_df = pd.read_json("training_set.json")
test_df = pd.read_json("test_set.json")
# hashtag_corpus = pd.read_json("NTUSDFinCorpus/NTUSD_Fin_hashtag_v1.0.json")
# word_corpus = pd.read_json("NTUSDFinCorpus/NTUSD_Fin_word_v1.0.json")
emoji_corpus = pd.read_json("NTUSD_Fin_emoji_v1.0.json")

# %% [markdown]
# emoji_corpus

# %% [markdown]
# conditions = [
#     (train_df['sentiment'] == 0) ,
#     (train_df['sentiment'] <  0) ,
#     (train_df['sentiment'] >  0)]
# choices = ['neutral', 'bullish', 'bearish']
# train_df['classes'] = np.select(conditions, choices, default='neutral')

# %% [markdown]
# # Pre-Processing

# %%
#placeholders 
rep = 0  #index for placeholders
p_mentions = [" @mentions ", " "]
p_cashtag = [" @cashtag ", " "]
p_url = [" @url ", " "]
stopwords = set(stopwords.words("english"))
qmark = " qmark "  
emark = " emark "

# %%
w_tokenizer = WhitespaceTokenizer()
lemmatizer = WordNetLemmatizer()
def lemmatize_text(text):
    return ' '.join([lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)])

# %% [markdown]
# #### processing steps
# - lowercase conversion
# - replace mentions
# - replace cashtag
# - replace urls
# - replace special unicode characters (&, > , < ,' )
# - removing stopwords
# - lemmatization
#
# yet to do
# - number processing
# - emoji

# %%
train_df['tweet'] = train_df['tweet'].str.lower()
train_df['tweet'] = train_df['tweet'].str.replace('([@][\w_-]+)', p_mentions[rep], case=False)
train_df['tweet'] = train_df['tweet'].str.replace('([$][a-z]+)', p_cashtag[rep], case=False)
train_df['tweet'] = train_df['tweet'].str.replace('http\S+|www.\S+', p_url[rep], case=False)
train_df['tweet'] = train_df['tweet'].str.replace('&amp', " & ", case=False)
train_df['tweet'] = train_df['tweet'].str.replace('&#39;', "'", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&gt;', " ", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&lt;', " ", case=False)
train_df['tweet'] = train_df['tweet'].str.replace('\?', qmark, case=False)
train_df['tweet'] = train_df['tweet'].str.replace('!', emark, case=False)
train_df['tweet'] = train_df['tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
train_df['tweet'] = train_df['tweet'].apply(lemmatize_text)

# %% [markdown]
# preprocessing steps taken for test dataset is the same for training dataset

# %%
test_df['tweet'] = test_df['tweet'].str.lower()
test_df['tweet'] = test_df['tweet'].str.replace('([@][\w_-]+)', p_mentions[rep], case=False)
test_df['tweet'] = test_df['tweet'].str.replace('([$][a-z]+)', p_cashtag[rep], case=False)
test_df['tweet'] = test_df['tweet'].str.replace('http\S+|www.\S+',  p_url[rep], case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&amp', " & ", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&#39;', "'", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&gt;', " ", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('&lt;', " ", case=False)
test_df['tweet'] = test_df['tweet'].str.replace('\?', qmark, case=False)
test_df['tweet'] = test_df['tweet'].str.replace('!', emark, case=False)
test_df['tweet'] = test_df['tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))
test_df['tweet'] = test_df['tweet'].apply(lemmatize_text)

# %%
for tweet in train_df.tweet:
    if "." in tweet:
        print(tweet)
# Out:
# @cashtag looking sexy morning...$600 break volume it's gone.
# whole food @cashtag may feel price competition @cashtag way go price wise compete kroger. @cashtag @url
# there's reason @cashtag can't get back $1,000 within next 3-5 years.
# nice name watch tomorrow @cashtag long $8+, @cashtag short $1.85-2.00. @cashtag @cashtag @cashtag potential r/g @cashtag short $11. #stocks
# good morning emark here's trending among #investors morning. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag patent turn signal detector autonomous cars. @url @url
# sftw investor long-term stock recommendation: @cashtag costco wholesale corp. (ss: 18) @url
# amazing @cashtag 300b market cap make le profit sale @cashtag watch. 300b valuation apple watch business qmark
# @cashtag @cashtag higher expected, @cashtag much lower, hmmm. @url
# facebook suddenly realizing snr problem newsfeeds. took ya long enough. @cashtag #facebook
# don't look #amazon & ; #bezos done again. quietly, #echo #alexa become next major platform. @cashtag @url
# bullish @cashtag day trade setup open close 27/34 ( 79% ) wins, avg 1.5% -&gt; @url
# reason caution chinese stocks. @cashtag @cashtag @cashtag @cashtag @url
# @mentions @mentions 2/ @cashtag inst. ownership 70% actually isn't egregious anyways, @cashtag @cashtag @cashtag higher
# dow worst performer chevron -0.47 nike -0.52 best performer ibm +1.33 apple +1.48 @cashtag @cashtag @cashtag #stocks #investing
# yahoo stock $36.46 bidding war pick company @url @cashtag @url
# @cashtag long. @url
# closed buy 1.0 lot @cashtag 15.28 +66.0 pips, total today +66.0 pip @cashtag @cashtag @cashtag visit @url trade
# i've picking railroad stock retirement acct. @cashtag @cashtag @cashtag 20-30% last 12 months.
# ah bottom losses: @cashtag -21.9% @cashtag -16.9% @cashtag -15.0% @cashtag -13.8% @cashtag -11.9% @cashtag -11.8% @cashtag -10.8% @cashtag -8.1%
# watch 1385. getting ready sell premiumm. @cashtag @url
# sound bullish. @cashtag @url
# @cashtag fck bird emark @cashtag soaring. buy first backtest broken resistance. here. overbought. #tradeideas #stocks
# rally friday emark #new52weekhighs big small @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - 31%. fine weekend emark
# rally friday emark #new52weekhighs big small @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - 31%. fine weekend emark
# @cashtag support @ 50sma, bb lower band, 50% retrace prior move. tomorrow dev. conf. good long trade, tight stop @url
# minnesota 1st quarter earnings season kick fastenal, @cashtag 1q revenue 3.5% - earnings 1.1% - result short expectation
# @cashtag back highs. @cashtag energy play. @cashtag trying break 5 day range. @cashtag 3.69 long #stocks #investing #tradeideas
# @cashtag taking shine @cashtag @cashtag @cashtag words.
# u.s. airline battle cuba route @cashtag @cashtag @cashtag @cashtag @url
# @cashtag call sweeper stepping morning. $230 wait.
# wondering @cashtag @cashtag catch bid today @cashtag news. sector taking beating recently, could positive
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @mentions ahhh... secret curing #overbought condition stock. good one, @mentions emark @cashtag #autostocks
# wondering @cashtag @cashtag catch bid today @cashtag news. sector taking beating recently, could positive
# @cashtag make hod. longs @ 33.10 33.58.
# nice name watch tomorrow @cashtag long $8+, @cashtag short $1.85-2.00. @cashtag @cashtag @cashtag potential r/g @cashtag short $11. #stocks
# bullish stock twitter dip. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag more: @url
# would feel terribly good recent order @cashtag today's recall.
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag 26.37
# j rae chipera placed order sell 5 share apple inc. ( @cashtag ) @url
# @cashtag 2.2% w/div since original call, @cashtag 0.6% even w/ fri's div. #emh damned. still holding.
# #fintech provider @cashtag cachet financial solution surging forward today post earnings +13.26% @url @cashtag @cashtag #momo
# @cashtag dropping ~$7b market cap they're losing $400m @cashtag 's business may tad bit overreaction.
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag speculation - positive outcome w/ lung study5/8 may see 13d filing soros @cashtag icahn @cashtag et al.
# homebuilder - @cashtag breaking support, watch one. @cashtag
# @cashtag big dumping... would touch
# @cashtag love type articles. s interest rose 12/15 day hit lows. @url
# added @cashtag 64.33 (64.13 low)
# rt @mentions @mentions @mentions @mentions @cashtag - $23 end week..did snatch ur 21 qmark blinked ur eye u missed
# @cashtag 7$ le 700,000 tape (dont know avg. vol, may alot stock still 100m every $ isthin @cashtag
# today's close (8/15/14), i'm long @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - longer-term, technical swing long basis.
# bot @cashtag 68.70; bot @cashtag 25.50;
# surprising see @cashtag @cashtag sale number still holding well. guess high end might concern all.
# @cashtag free net africa @url first roi piss investor big picture brilliant. boy-wonder visionary zuck emark
# @cashtag nice volume.watch 330 resistance
# @cashtag sell flat..i out..
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# published @cashtag estimate estimize: +0.71 eps +66.70m rev compared wall street's consensus. @url
# &quot; @mentions : @cashtag @cashtag green, lol... make-up cover ugliness #ftw @url &lt;-- r yesterday boom today
# plan rest week - holding @cashtag @cashtag stops, accumulating @cashtag pullback..
# @cashtag something big gonna happen here... much pre market trading going on...keep eye open.
# rival company @cashtag watco eyeing @cashtag w take-over interest. @url
# @cashtag cold put dent massive horizontal rig production. know @url
# three hot stock today @cashtag @cashtag @cashtag ... thanks @mentions
# rt @mentions @mentions ...since @cashtag mastered supply chain // cornering nand, apple mastered everyone's supply chain emark
# @cashtag institutional ownership 30.74% q/q, 5,992,420 net purchase @url
# #sectorbreadth strongest sector industrials ( @cashtag ) 86% bullishness. weakest energy ( @cashtag ) 57%.
# @cashtag facebook - bull candle $4.06 (5:52%) - @url
# meanwhile absolute garbage still up. @cashtag store totally empty. inventory galore. stock mispriced @cashtag
# long position @cashtag ,...updating @url
# @cashtag new hod 7.9x
# 2013 longs(12/31/2012 close) @cashtag &gt;2.89 @cashtag &gt;2.89 @cashtag &gt;8.44 @cashtag &gt;20.99 @cashtag &gt;34.69 @cashtag &gt;51.00 @cashtag &gt;1.30 &gt;&gt;&gt; i'm up( +8.332% ) qmark
# @cashtag @cashtag @cashtag ah @cashtag beat.
# rt @mentions @cashtag still rising rsi & ; macd, bond buying signaling bad move market. @cashtag @cashtag
# @cashtag 25% since tue morning.
# @cashtag nov 90 call 2.08 .. go long exp imo emark unless european keep f'ing around emark
# @cashtag bought little yesterday, hoping earnings pop.
# @cashtag get 26 patent go $10, @cashtag get patent go .20 today.
# @cashtag qq case noticed...short percent float 16.80%
# @cashtag took small position- hopefully better outcome getting kneecapped @cashtag selling dirt cheap 36.50
# @cashtag @url continues base weekly chart selling last weeks.
# japan earnings: 12% topix company reported, yoy eps growth around 12% far. @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag making new high year. doesn't normally produce great stock trade, @cashtag $39 may bad swing. @cashtag
# @cashtag won't matter beat er - looking ahead investor nervous outlook, be.
# @cashtag 5.43 % - megaphone watch
# &quot; @mentions : @cashtag happened shorting $26 neg pumpers....oh, you're still here.
# @cashtag running. chart 6/17. @url
# add @cashtag @cashtag position posted earlier. (exit @cashtag )
# @cashtag missed big time @cashtag low 2's back nov. 2012, get punked one, 3.61
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag &gt;&gt; agreed @cashtag @cashtag downness
# @cashtag still trouble resistance line. resolve soon. @mentions @mentions @url
# add @cashtag @cashtag position posted earlier. (exit @cashtag )
# @cashtag .ca {head & ;shoulders} bullish reversal setup breakout. oil gas pipleline stock. @cashtag
# sound like cost cutting @cashtag run course, tom long need find way turn around miller lite quickly.
# @cashtag starting creep @cashtag sits near hod ...
# @cashtag #215. forget chart. invest elon. fund acjieve misson faster, would contribute without doubr emark
# close week minuscule 0.09% gain @cashtag lost handsome gain friday. portfolio 6.2% ytd @url
# @mentions lost 600 like 3 day @cashtag investment. sure wish bad news came day earlier. think i'll go russia emark
# loaded @cashtag yesterday,looking good now. still think way upside downside.
# one routing trade knight capital. receivable going zero. @cashtag
# @cashtag gap fill 53.53 still waiting.
# @cashtag afternoon selloff usual brutal. get ready lose ton money.
# @cashtag _f good santa rally without improbable blow top finishing touch... @cashtag
# @cashtag wrong, berkowitz didn't add 2.7m shares. added 3.47m q4 2013 (from 20,758,000 24,226,073)… increase 16.7% emark
# @cashtag sierra. great cash balance impressive growth rate.would wonderful marriage emark
# @cashtag got 2.82
# rt @mentions 10 favorite stock (and trends) 2013 @cashtag @cashtag @cashtag ... @url
# 18-11-2013 @cashtag buy $68.74 mental-stop around $67.05 target $70.80 @url
# @mentions last year mkt fell debt downgrade early aug. & ;p500 corrected 10% dg due slow growth @cashtag
# @cashtag run run @cashtag 4.4%
# today's close (8/15/14), i'm long @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - longer-term, technical swing long basis.
# @cashtag @url cien seems broken major horizontal resistance. target $14.35.
# @cashtag @cashtag @cashtag time stomp dreams.
# @cashtag speculation - positive outcome w/ lung study5/8 may see 13d filing soros @cashtag icahn @cashtag et al.
# @cashtag test 12.85 coming
# @cashtag people shortsighted. opened red significantly. day continue surge next week.
# @cashtag @url long setup. macd cross.
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# rt @mentions @cashtag @url long 3.95/great find - hope wold another @cashtag @cashtag still holding second 1/2 @cashtag
# watch bancos.they're holding relatively well compared broad market @cashtag @cashtag @cashtag @cashtag &lt;--large c buying @cashtag backburner
# @cashtag ..ripe squeeze emark
# @cashtag beautifully orchestrated market, again. would like know mm fb is.
# @cashtag 7$ le 700,000 tape (dont know avg. vol, may alot stock still 100m every $ isthin @cashtag
# @mentions don't limit @cashtag $4 let run. @cashtag losing 8.25 stop it, they/we buying @cashtag @url
# @cashtag frustrating. every tall green bar get followed immediately 1-3 week consolidation.
# @cashtag & ;t issue statement debt ceiling, potential u.s. government default
# @cashtag @cashtag good news domestic automakers.... @url
# @cashtag saying peak fear mongering. competition's dying, smartphone usage increasing. watch coming.
# @mentions @cashtag - thanks sanity amidst cheerleading around deal. one cheerleader show actual valuation work qmark
# three hot stock today @cashtag @cashtag @cashtag ... thanks @mentions
# @mentions i'm saavy, @cashtag drop $5.15, i'm in, push @cashtag investment another time.
# okay i'm looking add gold miner possibly lower pe tech name close/ tmrw. watching @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag @url daily chart - though rsi stoch. point possible move up, there's lot resistance.
# @cashtag selling cc.
# @mentions gots @cashtag morning...
# @cashtag look like longer term top building may take time quickie short fill least 1st gap 313.82.
# would guessed @cashtag would kill @cashtag @cashtag would suck...not lol
# @cashtag looking good. need 9/10 stay support. note broke area lighter volume. good sign
# @cashtag see q2 2014, total net revenue $780 mln $790 mln, yoy growth rate approximately 122.0% 124.9%.
# @cashtag still interesting finance play... one since 14's- hold
# &quot; @mentions : @cashtag soar pre-market business split announcement; rumor @cashtag looking shed @cashtag stake @cashtag buyer.&quot; lol @cashtag
# @cashtag downgrade bias. stock buy.
# @cashtag tight price 3 consecutive weeks.
# @cashtag crazy emark index engineered u...but little confidence prev. hi beta hi performer @url
# lot metal stock look like 5-10% run awaits. long @cashtag @cashtag @cashtag high quality name go metal price cooperate
# @cashtag @cashtag trying lead higher here... gonna tough
# praise.. bad.. bad bad rt @mentions rt @mentions @cashtag bought back share today&lt;~good u. im ridin w/ ya emark
# @cashtag sold xoma.. buy back april 1.
# @cashtag @cashtag short/put position looking good here. wait market downturn confirm
# institution seem like class stocks. 85-90% share @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag got hit hard lower --&gt; look like found support 18.89 @url
# @cashtag biggies must loading lows..
# &quot; @mentions : @cashtag wkly, inverse head shoulder forming, trigger 18.50, po least 30.80, watching @url
# @cashtag embarrassing china numbers. imagine facebook going china signing 1 million users. expectations.
# @cashtag @url bounced target buy area, bought @cashtag hedge. watch 50ma's slope
# @cashtag @url possible target around 127.4 (neckline, sma200, fork congestion). @cashtag @cashtag @cashtag @cashtag
# @cashtag @url long setup. closed 20ma. macd cross. november catalyst.
# @cashtag bumping head declining daily 8ma overhead resistance. big brother 50ma that.
# rt @mentions correleation dollar index @cashtag simply amazing. @cashtag find support, @cashtag retreat like clockwork
# @cashtag keep stock watch list, much cause tape. strange buying today
# rt @mentions seem @cashtag long market comment qmark lol - thinking same...
# @cashtag +0.96% 621.59. weekly 625 call +42.31% 3.75: @url
# @mentions @cashtag bull @cashtag bear, way u cut it. @cashtag @cashtag
# @cashtag would consider opportunity add position company right track still improving sales...
# @cashtag brent back 49, what's wti 45 qmark hahaha, yes, go 44's soon.
# @cashtag u govt chasing @cashtag joke.. case here..
# @cashtag brand name big fail, bet recover get bought year over. get high low
# @cashtag @cashtag @cashtag ah @cashtag beat.
# @cashtag many time find top bottom short start rejoicing bull start rejoicing. currently short rejoicing
# rt @mentions @cashtag top upstream mlp ranked estimated 3 yr forward yield tax undiscounted 28.8% (long @cashtag )
# @cashtag look like might break down. i'm
# rt @mentions @cashtag @url long 3.95/great find - hope wold another @cashtag @cashtag still holding second 1/2 @cashtag
# bot @cashtag 68.70; bot @cashtag 25.50;
# @cashtag @url like &gt; 15.80 trade 200 sma & ; 50% fib 15 month range- 7% short int & ; report 11/10
# @cashtag short... @url
# @cashtag chunk dec $35 put bought .40â¢ - opening
# @cashtag getting attention. no.2 nyse 100 top buying list @url
# @cashtag 580+ coming quick, fed support market 610.
# @mentions true short market using plenty reverse etf's alternative rather bubble creation. @cashtag
# @cashtag .ca @cashtag competitor worry blackberry inevitable successor northern telecom,but much competent leadership.
# @cashtag : 5.4 highest close since nov. 14th (day gap down).
# @mentions much would like @cashtag capture back market share @cashtag cleary surpassed bb long time.aka android
# @cashtag may risky rush, i'll give emark make sure don't go long money. play safe, long.
# @mentions yeah qmark even @cashtag looking pretty attractive versus @cashtag pig. sox trading @ 36x reported earning @cashtag
# @cashtag closed short position. small gain. interested option expiring worthless
# @cashtag move bring @cashtag close. see.
# @cashtag @cashtag holding well today.
# eur/usd finding support near 1.10 level @cashtag @cashtag @cashtag @cashtag @url
# blackberry messenger second facebook user loyalty, say new study: @url @cashtag @cashtag .ca @cashtag
# train cellar ..&quot; @mentions : w bottom look like. confirmation hold 136.50 @cashtag
# index & ; industry group track closed friday r line new highs. @cashtag @cashtag @cashtag 50 @cashtag 20 @cashtag @cashtag
# @cashtag beautiful trend/base, technical pointing up. solid accumulation. @mentions look good. weekly next. @url
# @cashtag heading back $2 region, really need hold 2's. sure go without news...
# @cashtag & ; @cashtag want go morning it's time looking chart.
# today's close (8/15/14), i'm long @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - longer-term, technical swing long basis.
# @cashtag stomach high risk left. that's extremely sensitive nasdaq
# @mentions men sell @cashtag puts.
# @cashtag - 9% run watch list winner, can't blame anyone taking profit today.
# @cashtag upside today. thing severe low float. catalyst guy. run.
# @cashtag stuff. looking add share get new high breakout.
# @cashtag wk2 212 1.48 - watching spy 60 min sto push - note price 200ma - rush - wait buyer
# @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag heavy volume alert. 50:50 split defensive cyclical sectors. edge offered
# @cashtag look weak now. v bottom yet over. may around 188 level see it. stay short spy till then.
# @cashtag small pos, short 180 wkly puts.
# would guessed @cashtag would kill @cashtag @cashtag would suck...not lol
# @cashtag @url closer inspection. resistance 10 point north 200d downward trendline. chart 2 2.
# eur/usd finding support near 1.10 level @cashtag @cashtag @cashtag @cashtag @url
# google, inc. completes acquisition icoa, inc. @url @cashtag @cashtag
# @cashtag @cashtag reporting today @cashtag reward better good earnings sold .50 last two day yet @cashtag rallied
# rt @mentions @cashtag look primed also @cashtag poised run too...
# play tmrw: @cashtag (52m,12%,0.55) @cashtag (638m,1.42,2cc) @cashtag (146m,6.6%,0.72,2cc) + watch @cashtag housing sector. @cashtag (78m,16.7%,0.61)
# @cashtag beaten down, hated, etc. hhhmm opposite 700&gt; happens next qmark
# @cashtag share ~7% hours; q4 eps 67c, beat 7c; see q1 adj-eps 54-59c, vs. cons. 58c, sale $1.025-$$1.075b, vs. cons. $1.05b
# @mentions sell credit spread. may one money. call credit spread @cashtag
# @cashtag hitting everything sight.short it. twtr
# headline read: &quot;saudi's capable increasing oil capacity reserve decline.&quot; @url @cashtag @cashtag @cashtag
# @cashtag pushed jack monkey's. thing b short $3 soon. gonna add sedond short somewhere high 14's get
# @mentions @mentions @cashtag yep lowered target 50% gain levels.
# u add 321k job november, since 2012, unemployment rate remains 5.8% gold future $16 $1191 @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag move bring @cashtag close. see.
# @cashtag 0.80 right also look like nice risk/reward starting initiate position. waiting fda feedback krn5500
# rt @mentions 10 favorite stock (and trends) 2013 @cashtag @cashtag @cashtag ... @url
# @cashtag @cashtag good news domestic automakers.... @url
# @cashtag @url would need clear $587.00 tomorrow 38 million share highest volume last 10 day
# @cashtag run run @cashtag 4.4%
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag &gt;&gt; agreed @cashtag @cashtag downness
# done copious research short @cashtag thesis. typed @cashtag news @url
# @cashtag post &quot; stream bullish, im brave, look im short&quot;.. going biggest billion $$ bb history
# 8 breakouts: @cashtag (stop: $17.99), @cashtag (200-day ma), @cashtag (gap), @cashtag (gap). one sub-$1 stock. modest selection attempted swing low.
# @cashtag may take day wks month watch happened @cashtag @cashtag ipo. mrkt need washout. hunt well need 2 wait stalk.
# rt sold 1/2 position @$5.70 +$.80 @mentions long @cashtag oct $240 call @ $4.90
# @cashtag looking oversold bounce.
# rt @mentions rt @mentions breadth consolidates: week steady gains,advances mkt breadth slowe... @url @cashtag
# @cashtag topping tail 5 min. chart 7.31 short here.
# rt @mentions @cashtag wtf emark complaining. got $4.50 playing emotions.amen decent co get bought imho
# @mentions @cashtag doesn't make real money. barely hang on. don't pay 10-11 bux it's worth it.
# @cashtag support 212.93 support 209.45
# @cashtag @cashtag @cashtag time stomp dreams.
# @cashtag @cashtag holding well today.
# given broad market environment, expect @cashtag trade work flawlessly. buy aggressively pull back 62 hold
# @cashtag ex-dividend coming fall more...i hoping $25 rebound sure anymore
# covered @cashtag short @mentions .80
# @cashtag might selling ahead @cashtag earnings...
# @cashtag think may start avoid bios except perhaps day trade there. whole they're well presented flyers....
# 2013 longs(12/31/2012 close) @cashtag &gt;2.89 @cashtag &gt;2.89 @cashtag &gt;8.44 @cashtag &gt;20.99 @cashtag &gt;34.69 @cashtag &gt;51.00 @cashtag &gt;1.30 &gt;&gt;&gt; i'm up( +8.332% ) qmark
# @cashtag & ; @cashtag ~i shopped 2 store black friday: 2 retailer whose stock own, course emark luv 2 shop online jammer =^.^=
# @cashtag get 26 patent go $10, @cashtag get patent go .20 today.
# 75k went ask 3.01 @cashtag
# @cashtag high risk could sweet st runner jigginess exits. 13 13.50+
# @cashtag @cashtag trying lead higher here... gonna tough
# @mentions @cashtag fast money say short ahead black friday...seriously qmark emark qmark
# @cashtag @cashtag watching china ppi cpi reporting tonight. commods super sensitive china still. could offer support revisit jump long bus qmark
# @cashtag short 592.49
# 2nd raise year. &quot; @mentions : @cashtag questcor increase quarterly cash dividend 20 percent.. @url
# @mentions @mentions @cashtag doesn't know got new product sept. thats next q good short bull expect new release
# @cashtag @cashtag baltic dry index lower 8 day 30 years... @url
# @cashtag hearing new ceo think company could crm voip...giddy emark
# @cashtag bull lucky enuff get upside gap fill, better take it. wouldn't chase here. @url
# @cashtag @cashtag @cashtag @cashtag holy green day batman. luv plan come together. tks @mentions half pick days.
# @cashtag seems like good short setup. stop 50 day. position.
# japan earnings: 12% topix company reported, yoy eps growth around 12% far. @cashtag @cashtag @cashtag @cashtag @cashtag
# sure wish hadn't scaredy cat yesterday bought @cashtag - almost 11% now. =^.^=
# @cashtag later riser, like last days. jan. 14 healthcare conference presentation. positive catalyst qmark
# @cashtag _f good santa rally without improbable blow top finishing touch... @cashtag
# index & ; industry group track closed friday r line new highs. @cashtag @cashtag @cashtag 50 @cashtag 20 @cashtag @cashtag
# @cashtag tomorrow party time bear emark emark @cashtag @cashtag -5.5%
# @cashtag glorious stuff...the selling day appear exhausted, back btfd, old school stuff....after 7 7.20, 8, 9, 10, etc.....
# @cashtag one good announcement, short start quietly covering, people buy, it's quick large gain. don't listen neg bs..
# @cashtag aug 645 call +550% .67c: @url
# @cashtag well go..at least know sector white hot next week..huge buy names.. @cashtag @cashtag @cashtag @cashtag ..nice work
# @mentions europe bank implode. stress test failing big swirl near bonds, cds, debt, cash gold. @cashtag selloff qmark
# @cashtag & ; @cashtag ~i shopped 2 store black friday: 2 retailer whose stock own, course emark luv 2 shop online jammer =^.^=
# covered small @cashtag short @ 7.99 .16 loss. flat day. cash now.
# @cashtag reviewing nflx gmcr's massive recent recovery toward new high give real shareholder encouragement questcor.
# @cashtag goldman suks can't bring one day today. look strong solar rebound today emark
# new recommendation carl kirst bmo capital market @cashtag buy.price target $62: @url
# rt @mentions @cashtag going end red&gt;&lt; highly doubt it..
# @cashtag near 3% drop thats lot... best hold er lol
# happy @cashtag watch everyone tuesday night serious breakout...already got 5 email people got in...booyah
# @mentions also betting @cashtag buy twitter. heard first.
# today's close (8/15/14), i'm long @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - longer-term, technical swing long basis.
# @cashtag long 1/2 position 137.89
# @cashtag @url breakout regional banking.
# @cashtag somewhat tempting long side here. inverse cuppa joes.
# new bullish conversation activity @cashtag quiet past 48 hours.
# @cashtag #17 @cashtag #10 ibd50 list. look good
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag &gt;&gt; agreed @cashtag @cashtag downness
# @cashtag speculation - positive outcome w/ lung study5/8 may see 13d filing soros @cashtag icahn @cashtag et al.
# go @cashtag go get bermuda triangle plenty daylight above.
# institution seem like class stocks. 85-90% share @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag many people met person fb mentioned waiting iphone5 upgrade phone. going epic
# @mentions good thing @cashtag learnt integrating device together tv.
# @cashtag selling far over. week ago noted large bearish channel formed measured move $42 @url
# @cashtag it's infinite valuation downgraded today, big buyer open supports. would imagine trade red least day
# @cashtag reliably finding cancer mutation urine lung cancer, colon cancer, pancreatic cancer, melanoma, thyroid cancer etc. jackpot
# @cashtag _f. nice little cup-and-handle shaping 15-minute. end-of-day @cashtag @cashtag favour good day index. see gap open
# @cashtag look like bouncing. would nice finish $6 today, make hammer. nice volume 5.77 bottom. finger crossed
# blackberry messenger second facebook user loyalty, say new study: @url @cashtag @cashtag .ca @cashtag
# @cashtag wayyy overvalued right imo. trading single digits. may take short pos. earnings. near term target 18 ......
# surprising see @cashtag @cashtag sale number still holding well. guess high end might concern all.
# @cashtag gaining momentum emark nice buy signal emark long $35.92 @url
# @cashtag trade continuing nicely yesterday, almost $3 yesterday entry, deal pricing tonight looking strong here... @cashtag
# @cashtag take can.
# @cashtag bought call omnivision tech $16 exp 12/21/13 today earnings. beat earnings.
# rt @mentions @cashtag cult stocktwits actually disgusting. want karate chop them/my bat.s ready never bring k-chop bat fight emark
# japan earnings: 12% topix company reported, yoy eps growth around 12% far. @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag god. market getting crushed today. gotta hold anything g recover tomorrow imagine.
# 2013 longs(12/31/2012 close) @cashtag &gt;2.89 @cashtag &gt;2.89 @cashtag &gt;8.44 @cashtag &gt;20.99 @cashtag &gt;34.69 @cashtag &gt;51.00 @cashtag &gt;1.30 &gt;&gt;&gt; i'm up( +8.332% ) qmark
# @cashtag reiterating newbies, notice doomsaying bear disappear climbs. they're opportunists. ignore them, make $
# @cashtag watch showing serious demand. it's gonna blow minds. better prepared
# taking $0.69 emark 520.72 &quot; @mentions : back @cashtag 520.03, stop 519.49&quot;
# casino red bell: @cashtag -0.75%, @cashtag -0.47%, @cashtag -0.47% &gt; unusual comibinations what's running, what's red bell
# u add 321k job november, since 2012, unemployment rate remains 5.8% gold future $16 $1191 @cashtag @cashtag @cashtag @cashtag @cashtag
# @mentions @cashtag lovaza 90k script week. really think 4 week capture 10% qmark impossible.
# @cashtag friday last chance $2....
# @cashtag well stand corrected cause excellent factual bear argument. ha
# @cashtag relative weakness pretty apparent short boat getting full one. prefer boat closer empty.
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# #amex mover +nhs @cashtag #restaurants 24.75+9% nh w #bigboy div, @cashtag triangle #petroleum 9.80+3% 2m expanding caliber @url
# @cashtag @cashtag usa new home sale (mom) nov -2.10% v -0.90% est; prior revised 25.40% 17.60%
# @cashtag break new highs, lot technical looking great right now.
# failed breakout & ; failed setups. limping crutch next week @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# rt @mentions think shorting close might play, @cashtag - high beta reversing..looks worth shot
# @cashtag hows oil &lt; $60 sound...good economy
# @cashtag gold going parabolic... wonder qmark @cashtag @cashtag @cashtag ... keep chasing top boys.
# @cashtag @cashtag @cashtag @cashtag inside week buy triggers. @url @url
# @cashtag hangin thread. 1click away cliff drop.. need follow (or snap-back vix)
# rt @mentions @cashtag @url long 3.95/great find - hope wold another @cashtag @cashtag still holding second 1/2 @cashtag
# greece, fomc much week. move side possible - larger range though. stay nimble cautious. @cashtag
# @cashtag would take profit them...
# @cashtag brutal slide. feel better way up. still long.
# @cashtag @url look good weekly chart.
# watch bancos.they're holding relatively well compared broad market @cashtag @cashtag @cashtag @cashtag &lt;--large c buying @cashtag backburner
# @cashtag covered swing -.50
# @cashtag tomorrow party time bear emark emark @cashtag @cashtag -5.5%
# @cashtag look really toppy right here.
# @mentions @mentions surprising would pull something like that, considering small business called @cashtag scam years.
# @cashtag weekly 120 put +283%, .21 x .24, 1900 vol: @url
# @cashtag looking good $58.65. call active month weekly
# look like big feb 18-22 @cashtag spread @cashtag last quarter 0% yoy rev growth trading @ 24x earnings. may try short.
# equity index working positive engulfing march. @cashtag @cashtag @cashtag @cashtag @cashtag small-caps semi fakeout b/out.
# &quot; @mentions : @cashtag - another quiet week, possible stalling action thursday. need see volume @url
# @cashtag vision : near-term target $77.38 @url
# @cashtag point two facebook game accuses @cashtag copyright infringement. @url
# @cashtag may take day wks month watch happened @cashtag @cashtag ipo. mrkt need washout. hunt well need 2 wait stalk.
# @cashtag sure guy northland capital #cnbc recommends tesla straight face & ; $230 pt. #joke #bubble #buyerbeware
# @mentions do. suggest learn valuation see @cashtag worth $20 share $40.
# ivory tower loved @cashtag -8.30% booyah
# @cashtag good time buy. run come earnings qmark
# @cashtag morgan stanley tricky bastards. ran price er, gave upgrade, shorted down.
# @mentions yeah qmark even @cashtag looking pretty attractive versus @cashtag pig. sox trading @ 36x reported earning @cashtag
# failed breakout & ; failed setups. limping crutch next week @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag hearing rumour major joint venture announcement.
# @cashtag weakness could opportunity. look 64.85 best shot here. good sell nov put re-entry
# @cashtag announcing monthly divy week, see maintain 15% yield. @cashtag @cashtag @cashtag
# @cashtag shoot moon favorite pumper would say. u know u r. still luv u man. u make u laugh. here's hoping ur right emark emark
# @cashtag continues consolidate previous break area...
# @cashtag it's time start wonder &quot;do enough share qmark qmark qmark beast keep moving..&quot;
# @cashtag want take - want bad apparently. people still coming in. eod could explosive short get caught.
# @cashtag today aside setting another drop. 33 36 target.overvalued sector etf
# ready break @cashtag watching 55.7 @url
# okay i'm looking add gold miner possibly lower pe tech name close/ tmrw. watching @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag &gt;&gt; agreed @cashtag @cashtag downness
# &quot; @mentions : @cashtag soar pre-market business split announcement; rumor @cashtag looking shed @cashtag stake @cashtag buyer.&quot; lol @cashtag
# @cashtag 3x etfs, subject decay due daily rebalancing, careful holding. long term hold, @cashtag safer.
# market seems stuck mud.. @cashtag
# lot metal stock look like 5-10% run awaits. long @cashtag @cashtag @cashtag high quality name go metal price cooperate
# would like see @cashtag go back low 70's, next year could good year them. would like start adding soon
# @cashtag @ 11 a.m. qmark 'mini me' 'wanna be' bear raid qmark
# @cashtag getting sold here.
# @mentions @mentions @mentions need something catalyst. intel stagnant years. also @cashtag could pick em too.
# @cashtag lows, $1.50 $2.50 bk real possibility
# @cashtag @cashtag could lotto winners.
# @cashtag @url rather neutral bullish rather bearish. still stock picker market. @cashtag
# buying @cashtag last week play month. wish woulda pulled trigger
# &quot; @mentions : @cashtag 42.71% float short. lol @url
# @cashtag think realize interest level skyrocketed last two week well abroad, $00.00's
# rt impo fda wont allow mor 2 new subscrip diet drug next 2 yrs. 1st lorc. 2nd qnex. good luck @cashtag - long @cashtag c u @ $ 12
# @cashtag -0.05% 137.09. april 136 put -23% .73c, 33,000 vol: @url
# 333.0% increased bullish conversation @cashtag past 1 hour.
# @cashtag murray leaf competitor adidas. @cashtag diversifies. add international exposure. tennis. murray 2012 u.s. open & ; olympic gold.
# look like @cashtag taking small chill pill today.
# @mentions vwap 1.63, held trend line. lot radars. @cashtag
# @cashtag use bb10 device better feel investment. mile beyond competition frozen headlights.
# @cashtag - @cashtag still need fill 27.97 - decent supt here-expect upside 30 @url
# @cashtag daily phase 2 retest - price experiencing early rejection. retest qmark @url
# @cashtag +1.2
# &quot; @mentions : @cashtag @cashtag close 49...monday freewater fall&quot; like white water rafting :)
# @cashtag weak hand flushed metal miners. fear selling. guess buying qmark mr greed.
# $$ stay long @cashtag next 3 4 years.
# rt @mentions new post: &quot;breakaway gap u.s. stock index -- short trapped due cme rule.&quot; @url @cashtag @cashtag _f
# @cashtag what's great move. still hold since back day yesterday. marry christmas:-)
# multi top @cashtag chart finally lead fall price. stability questioned stock coming week tell.
# @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag heavy volume alert. 50:50 split defensive cyclical sectors. edge offered
# i-grid show @cashtag capped long term range 123.40- 124.77;any rally beyond today's level range lead meltdown.
# @cashtag may take day wks month watch happened @cashtag @cashtag ipo. mrkt need washout. hunt well need 2 wait stalk.
# 2013 longs(12/31/2012 close) @cashtag &gt;2.89 @cashtag &gt;2.89 @cashtag &gt;8.44 @cashtag &gt;20.99 @cashtag &gt;34.69 @cashtag &gt;51.00 @cashtag &gt;1.30 &gt;&gt;&gt; i'm up( +8.332% ) qmark
# blame club terrible golfer @cashtag downgraded neutral wedbush, pt lowered 7.00
# @mentions chartist (news & ; mm talk orchestrated bs). long tech early jan, it's straight @cashtag @cashtag call
# @mentions i'm saavy, @cashtag drop $5.15, i'm in, push @cashtag investment another time.
# rt impo fda wont allow mor 2 new subscrip diet drug next 2 yrs. 1st lorc. 2nd qnex. good luck @cashtag - long @cashtag c u @ $ 12
# u add 321k job november, since 2012, unemployment rate remains 5.8% gold future $16 $1191 @cashtag @cashtag @cashtag @cashtag @cashtag
# &quot; @mentions : @cashtag soar pre-market business split announcement; rumor @cashtag looking shed @cashtag stake @cashtag buyer.&quot; lol @cashtag
# double bottom handle buy point 56.49 @cashtag @url
# @cashtag torture.......
# @cashtag making new high year. doesn't normally produce great stock trade, @cashtag $39 may bad swing. @cashtag
# @cashtag unusual opening buyer 8000 wwav jan15 35.0 call $1.45 ask ise 11:01:30 iv=30.2% +1.6 -- 14x usual
# @cashtag like optimism @cashtag moving ( nce ) agenda may simple ..... @cashtag claim active moiety
# @cashtag anyone long flush please accept condolences. congrats. short. wasn't either way.
# @cashtag - one watch much. would watch 8/21 ema's acted support now. position.
# @cashtag @url @cashtag patiently waiting price enter buy/support zone. strong support - note chart
# @cashtag 2.25 could get going qmark
# 112.35 gotta hold @cashtag
# @cashtag point two facebook game accuses @cashtag copyright infringement. @url
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag &gt;&gt; agreed @cashtag @cashtag downness
# &quot; @mentions : @cashtag 30-minute chart. small cap threatening descending triangle breakdown $110.20. @url
# @cashtag don't hang bull hat yet. next week pop higher qe3 hope back fed's 2 day meeting.
# @cashtag u volume ratio 2.7 & ; management ownership hold 57% total outstanding stock. major skin game...positive.
# 100.0% increased bearish conversation @cashtag past 1 hour.
# @cashtag sold today 3.13, 5.26 40% loss. well, should've attentive one, bad...moving on.
# @cashtag @url lee ready exit bankruptcy. strong volume today.
# @cashtag upgrade today m overweight. excellent company leadership
# rt @mentions @cashtag call/put buyer crushed...looks way...not happy it.
# @cashtag starting creep @cashtag sits near hod ...
# okay i'm looking add gold miner possibly lower pe tech name close/ tmrw. watching @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# rt @mentions @cashtag pre-order #s 1st weekend: ~9m imo #timestamp//1m sold pre order last year. 2m year would amazing
# @cashtag sold 139.26 flat
# @cashtag oh man... hospital reit slaughtered. even plus 6% div yield.
# new bullish conversation activity @cashtag quiet past 48 hours.
# @cashtag don't intend nay sayer, cuz love stock/co. may see 4.29
# u.s. consumer keep cautious stance @url #premarket @cashtag @cashtag @cashtag @cashtag
# @cashtag need anoth $1 time high. @cashtag new high..
# @cashtag @url long setup: one name (of many) coal sector displaying pattern.
# marriott win new starwood deal raising cash portion bid, worth $79.53/sh versus anbang's $78/sh @url @cashtag @cashtag
# longed @cashtag 300 @ 189.82
# add short 119.2 @cashtag
# @cashtag nice...
# @url verified $98.95 loss @cashtag trade
# loving volume @cashtag average higher yesterday already.
# @cashtag seems respecting channel...long v 147 stop seems good 2:1 r/r...7down/15up @url
# @cashtag kodak could pick christmas write taxes.
# @mentions lol wait... medium hate @cashtag they'll whip back
# @cashtag @url 30.37 kirby
# @cashtag got sell signal 7/1/14 still force target 1.50
# @cashtag suggest read report. future bright
# @cashtag 2012-2013 bull careful smack monitor .. @url
# rival company @cashtag watco eyeing @cashtag w take-over interest. @url
# @cashtag congrats analyst w. blair downgrade er. @url
# @cashtag downgrade @cashtag good opportunity buy. it, don't sell buy again. taxable event emark @url
# watching @cashtag @cashtag @cashtag higher, @cashtag @cashtag @cashtag lower. maybe fade metal gap.
# stock split, @cashtag could use cash buy back shares, instead dividend.
# watch @cashtag trade $189.52 print daily reversal candle. @cashtag got potential. @cashtag @cashtag changed.
# starbucks also doubled number store france 2010 2016. still 11 store portugal though. @cashtag
# @cashtag investor broke news company confirmed it, positive top notch investor dd trusted.
# @cashtag - it's important pragmatic analysis...high price could offer head-winds....bullish story intact,evenif market roll
# @cashtag telling u guys..this stock b/c european approval news..after news, nothing left. don't keep anymor
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# @cashtag @cashtag @cashtag time stomp dreams.
# @cashtag short term fund/redemption liquidations.. channel cleared soon solid footing. $520 new floor come july emark :)
# @cashtag pre mkt. look like gap filled....lookin 4 short opt
# @cashtag move tr1 long watchlist.
# bullish stock twitter dip. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag more: @url
# @cashtag accumulated day. coming potentail resistance
# walgreens boot alliance(pbr36) us warrant buy $1.17b & 14.97% amerisourcebergen(pbr16) shares. @url @cashtag @cashtag
# @cashtag well go..at least know sector white hot next week..huge buy names.. @cashtag @cashtag @cashtag @cashtag ..nice work
# @cashtag max pain 101.00. maturity 05/01/2015. previous close 105.01. @url
# @cashtag +2.76% trading @ $21.90
# @mentions @cashtag said possible qmark everyone buying call eod friday ;) question rest monthly opex. cash
# u.s. consumer keep cautious stance @url #premarket @cashtag @cashtag @cashtag @cashtag
# @cashtag - @cashtag still need fill 27.97 - decent supt here-expect upside 30 @url
# @cashtag swing short $368 w/pt $340 315 (maybe 280...will let know).
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# check out.. @cashtag 's owners.. must exciting eh qmark :-)
# equity index working positive engulfing march. @cashtag @cashtag @cashtag @cashtag @cashtag small-caps semi fakeout b/out.
# @mentions confused. long short qmark hope short, @cashtag 15 dollar stock.
# u.s. consumer keep cautious stance @url #premarket @cashtag @cashtag @cashtag @cashtag
# @cashtag 0.46 (6.98%) up*timing everything time canna security america#weed #cannabiz @cashtag #pots @url
# @mentions yes, expectation deal somewhat priced could see nice pop bid come higher expected... @cashtag
# @cashtag turn back early trading.... @url
# @cashtag resuming advance new historical highs.
# flat week, @cashtag short premium expire full gain, however @cashtag expire loss remaining 3/4.
# @cashtag - nhtsa give tsla highest safety score ever.will day world end nhtsa say wrong. long @url
# @mentions #aapl invest buy @cashtag & speed electric car development exponential way.aapl could jump 50% partnering tsla
# good morning emark here's trending among #investors morning. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# time go long @cashtag qmark "create bunch primitives, get way, take nice skim top." @url
# @cashtag need anoth $1 time high. @cashtag new high..
# @cashtag bull defend 19dma $236.75 next session #stocks #daytrading #investing #tradeideas
# @cashtag - broken downtrend - 200dma proving stiff resistance short term. @url
# ten year yield, weekly @url 10 year yield still bearish, hence 7-10 year bond fund @cashtag bullish. @cashtag too.
# @mentions : back saddle again. @cashtag around 17. stop 0.29
# blackberry messenger second facebook user loyalty, say new study: @url @cashtag @cashtag .ca @cashtag
# ive got 2k share @cashtag 6.51 sale emark
# whole food @cashtag may feel price competition @cashtag way go price wise compete kroger. @cashtag @url
# @cashtag 1%. curated reason @url
# 8 breakouts: @cashtag (stop: $17.99), @cashtag (200-day ma), @cashtag (gap), @cashtag (gap). one sub-$1 stock. modest selection attempted swing low.
# @url @mentions colin loved @cashtag $9 today trade $1.90, like @cashtag end @url
# rt @mentions @cashtag lauching 4 alien space..lol...in jan 2200 (analysts martian order way high theyll never hit emark )
# @cashtag @cashtag @cashtag @cashtag inside week buy triggers. @url @url
# @cashtag like optimism @cashtag moving ( nce ) agenda may simple ..... @cashtag claim active moiety
# coke dividend - 3%. google dividend - 0%. passive income coke take it. @cashtag @cashtag @url
# @cashtag still want higher think.
# @cashtag crazy market down.
# @cashtag @cashtag @cashtag @cashtag inside week buy triggers. @url @url
# watch @cashtag trade $189.52 print daily reversal candle. @cashtag got potential. @cashtag @cashtag changed.
# @cashtag heading 200dma certain doom hold there.
# stopped @cashtag 231.53 (3.86 loss)
# @cashtag many name talking apple cheap, must buy, $150+ stock price soon...hmmmmm
# @cashtag come back. :-) three earning yesterday. @cashtag shorted, 1% short float. @cashtag long. nice profit.:-)
# @cashtag delivering good let's see spill chinese internet names, @cashtag started wake last week. @cashtag
# published @cashtag estimate estimize: +0.03 eps +29.98m rev compared wall street's consensus. @url
# @cashtag aapl: gundlach slam ipad mini, see downside $425. @url
# #amex mover +nhs @cashtag #restaurants 24.75+9% nh w #bigboy div, @cashtag triangle #petroleum 9.80+3% 2m expanding caliber @url
# @cashtag cut outlook 6%. could see @cashtag @cashtag fall sympathy
# biggest gainer today large caps: @cashtag 10.17% @cashtag 8.93% @cashtag 7.71% @cashtag 7.44% @cashtag 6.91% @cashtag 5.27% @cashtag 5.17% @cashtag 5.05% @cashtag 4.61%
# alert: new macd signal created @cashtag - buy 77.09 - time: 18:23 - strength: 10. powered @url
# @mentions much would like @cashtag capture back market share @cashtag cleary surpassed bb long time.aka android
# @cashtag broke descending channel....will hold qmark
# deutsche bank downgraded starbucks co. @cashtag @url @url
# @cashtag 22% online grocery market. @cashtag 13%. @cashtag (ahold) 5% (kroger/stop&shop). @mentions 2%. @mentions @url
# @cashtag any1 somehow spinning er, stellar, something negative some1 got caught short it. rise 2morrow.
# okay i'm looking add gold miner possibly lower pe tech name close/ tmrw. watching @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# #yahoo finally take "harvest strategy" advice: @cashtag share climb. @url via @mentions
# rt @mentions @cashtag @url 31.85 look good
# @cashtag pivot area intraday chart- break could send 50-day sma, 457.80 @url
# @mentions think @cashtag bubble might go time. long ppl love cars, might keep getting funding.
# @cashtag cut outlook 6%. could see @cashtag @cashtag fall sympathy
# @cashtag @url possible target around 127.4 (neckline, sma200, fork congestion). @cashtag @cashtag @cashtag @cashtag
# rt @mentions day biotech good load confident. @cashtag @cashtag @cashtag @cashtag @cashtag >> agreed @cashtag @cashtag downness
# @cashtag congrats whoever bought 4- sold 4 i'm sorry...
# okay i'm looking add gold miner possibly lower pe tech name close/ tmrw. watching @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @mentions @mentions @mentions @cashtag get clean bill health audit. @cashtag india... @url
# @cashtag report q1 eps $0.37 versus estimated $0.35, beating $0.02. eps 19% quarter last year.
# 4-star analyst scott henry roth capital reiterated buy @cashtag scott +10.3% avg rtrn @url
# @mentions see #apple $150/share year (+36% today) growing service business. @cashtag @url
# play tmrw: @cashtag (52m,12%,0.55) @cashtag (638m,1.42,2cc) @cashtag (146m,6.6%,0.72,2cc) + watch @cashtag housing sector. @cashtag (78m,16.7%,0.61)
# @cashtag 195 call .78
# @cashtag said yesterday, apr.22 call getting hot...today getting paid @url
# @cashtag 2nd time test 21.20-30 b/o zone. still breaking out. moved stop 20.80.
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# @cashtag 91 support. @cashtag @cashtag @url
# @cashtag " resurgence stock price today might mean company may emerge stronger ever." @url
# @cashtag -0.75% #trading weak vs. @cashtag & @cashtag here#stocks #stockaction #fang
# @cashtag short cover high 30 go planned. lol
# bought @cashtag feb '16 you'd 60%. one obvious opportunity year
# watch bancos.they're holding relatively well compared broad market @cashtag @cashtag @cashtag @cashtag <--large c buying @cashtag backburner
# @cashtag similar pattern like beginning may. u sell qmark now..will go much higher drop.
# dumped @cashtag @cashtag maybe buy back another time.
# @mentions @mentions @mentions fine....imho...i worry @cashtag real deal here...holding
# @cashtag @cashtag watching china ppi cpi reporting tonight. commods super sensitive china still. could offer support revisit jump long bus qmark
# @cashtag i'm sure short holding breath hoping miracle. lol
# @cashtag 100% upside left next 6 mnths based @cashtag nov 2010 @cashtag 100% based @cashtag july 2007. history rhyme
# bullish stock twitter dip. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag more: @url
# u.s. airline battle cuba route @cashtag @cashtag @cashtag @cashtag @url
# casino red bell: @cashtag -0.75%, @cashtag -0.47%, @cashtag -0.47% > unusual comibinations what's running, what's red bell
# @cashtag taking shine @cashtag @cashtag @cashtag words.
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# that's folks. chen killed #blackberry. bet high-end android, mid. @cashtag killed former; killing latter. @url
# looking @cashtag stock make new 2013 high tomorrow.
# @cashtag q1 disappoints #software license down. real problem qmark #cloud growth trail @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag af bashing cytr twitter.
# @cashtag 's bod right reject offer. company low economy, type mismanagement anything.
# @cashtag right top thre cloud. position - @url @url #stockcharts
# index & industry group track closed friday r line new highs. @cashtag @cashtag @cashtag 50 @cashtag 20 @cashtag @cashtag
# adding put @cashtag mentioned earlier easier play right @cashtag short term.
# @cashtag like one lot.
# @cashtag actually lost .03c per share u incl vz debt 3.1 cash.
# @cashtag dip bought real quick. higher low fo sho
# @cashtag @url downside breakout look coming soon.
# @cashtag @url pot. cont. uptrend longerterm wly-dly-hly combo chart #netflix #stocks @url
# @cashtag love donut coffee. hate plunge 40. one time go $35 long term chart. perfect buy there.
# @mentions @cashtag guess haven't seen 3 month picture results. company's tech work better load
# @cashtag .ca {head&shoulders} bullish reversal setup breakout. oil gas pipleline stock. @cashtag
# @cashtag holding it's gain around $104.50 area. we'll see long
# bearish outside day tuesday significant. 200 day resistance still intact. opinion @cashtag @url
# @cashtag can't get back $212.20 lol jeez
# @cashtag $373.27, lower bollinger band $369.40 @url #regn
# utilities: still inside range ( @cashtag ) triangle ( @cashtag ) trying break >50-day sma served perfect support/resist 6 mos.
# @cashtag still holding 226 yday..no biggie
# bot @cashtag 31.30
# buyback trending right ( @cashtag spending share pricier). hopefully pull back w 6.87 q2 closing vwap
# @cashtag debt anyway eating 98% ebit.. becomes risk capital guaranteed interest payouts.. lost huge still hopeful
# @cashtag shorting pig qmark sound emotional. great way trade.
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# people thk @cashtag failure 'cos jst 20% user @cashtag has...bt they're forgetting potential relative value user
# sold @cashtag 45 @cashtag (down $1), hedging 45 @cashtag letting call ride solo now.
# u.s. active (stock wars): @cashtag +1.44%, @cashtag +1.28%, @cashtag +13.56%, @cashtag -3.61%, @cashtag +4.44% @url #stockwars
# @cashtag +5.10%, @cashtag +4.54%, @cashtag +3.53%, @cashtag +2.93%, @cashtag +3.04%, @cashtag +2.61%, @cashtag +2.27%, @cashtag +1.68%, @cashtag +1.49%, @cashtag +1.56% @cashtag +1.42%
# @mentions : cook supply chain expert. u think would allow @cashtag shortage deter @cashtag qmark //sorry longs, correction mode $$
# 2013 longs(12/31/2012 close) @cashtag >2.89 @cashtag >2.89 @cashtag >8.44 @cashtag >20.99 @cashtag >34.69 @cashtag >51.00 @cashtag >1.30 >>> i'm up( +8.332% ) qmark
# @cashtag take shot 10.40
# @cashtag hit 360 bounce it. time buy.
# notable gainer among liquid option name morning include @cashtag (+7.0%), @cashtag (+4.6%), @cashtag (+4.2%), @cashtag (+4.1%), @cashtag (+3.4%),
# @cashtag 14 day without even one dollar pull back...i see big day near future, dont know
# 2013 longs(12/31/2012 close) @cashtag >2.89 @cashtag >2.89 @cashtag >8.44 @cashtag >20.99 @cashtag >34.69 @cashtag >51.00 @cashtag >1.30 >>> i'm up( +8.332% ) qmark
# @cashtag 33% since 6/25 buy signal. resistance 5.33 - expect 1. pullback 2nd half day 2. break abov 5.33 & continue rally 4-5 day
# @cashtag increase annual dividend target $1.80/share $1.70/share
# today's close (8/15/14), i'm long @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag - longer-term, technical swing long basis.
# @cashtag #china #electriccar maker. china car sale +7.8%. also, may feed @cashtag momentum run lately.
# @cashtag look set fall further. @url
# pretty steady accumulation support today. purdy. @cashtag
# @cashtag hit high $3.61 emark +12.81% friday's $3.20 buy call emark @cashtag @cashtag @cashtag @cashtag @cashtag @url
# lot high flyer like @cashtag (no position) r getting wing clipped today. would blame 6-month comment yellen.
# @cashtag -4.44% 18 awful, 42.50
# @cashtag $2.66 support - hope hold look
# stole tweet. really wouldn't surprised took 423 pinned around rt @mentions could possibly even see425 today @cashtag
# putting little @cashtag short, prevailing wisdom notwithstanding. @url
# @cashtag @cashtag higher expected, @cashtag much lower, hmmm. @url
# @cashtag report q3 eps $0.14 v $0.11 est; revenue $328.1m v $328.18m est
# bullish stock twitter dip. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag more: @url
# rt @mentions @cashtag checkout chart. cautious u late party. @url
# @cashtag exit reversal .11 x 3k share $330 - long - getting follow through, either side price action
# adding put @cashtag mentioned earlier easier play right @cashtag short term.
# yahoo's getting lot attention, verizon still bidder beat. @cashtag @cashtag @url @url
# @cashtag yelp emark china onboard. looking good paris conference december. @url
# @cashtag @cashtag reporting today @cashtag reward better good earnings sold .50 last two day yet @cashtag rallied
# @cashtag worst stock 2015.
# institution seem like class stocks. 85-90% share @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag like idea people think it's safe market drops......not emark emark emark ...proven minute ago....
# @mentions @cashtag model x recall stock still green. x rocket qmark
# ah bottom losses: @cashtag -21.9% @cashtag -16.9% @cashtag -15.0% @cashtag -13.8% @cashtag -11.9% @cashtag -11.8% @cashtag -10.8% @cashtag -8.1%
# it's like christmas may.. @cashtag
# get wealthy #zuckerberg & @cashtag #fb added productivity like #gates #jobs #ford #ellison. fb's glorified scrapbook
# @mentions look like good entry @cashtag here.
# @cashtag 91 support. @cashtag @cashtag @url
# ah bottom losses: @cashtag -21.9% @cashtag -16.9% @cashtag -15.0% @cashtag -13.8% @cashtag -11.9% @cashtag -11.8% @cashtag -10.8% @cashtag -8.1%
# @cashtag u think pandora game changer please check spotfy...
# @cashtag support 12.50
# bullish stock twitter dip. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag more: @url
# know back seat qmark don't sit it. - @cashtag -> tesla recall 2,700 model x car @url
# @cashtag breaking good vol parser buy signal ..noticed bob langs comment looking 48 fast
# ah bottom losses: @cashtag -21.9% @cashtag -16.9% @cashtag -15.0% @cashtag -13.8% @cashtag -11.9% @cashtag -11.8% @cashtag -10.8% @cashtag -8.1%
# #fang 2015 vs. ytd 2016 @cashtag +34% vs. +5.7% @cashtag +118% vs. -12.0% @cashtag +134% vs. -9.2% @cashtag +47% vs. -2.4%s&p 500 -0.7% vs. +0.2%
# free money @cashtag 380, almost there. easy, sell open every day
# trade today...currently 167.1% net long...ended day 1.64% due @cashtag (-2.7%), @cashtag (-2.5%), @cashtag (-1.6%) @cashtag (-1.6%)
# google, inc. completes acquisition icoa, inc. @url @cashtag @cashtag
# @cashtag gift weekly 235s 6 play 4/30 announcement sell off. 220-200 target
# @cashtag trade mid upper range. break yet, either direction
# @cashtag squeezes, nakeds might lose everything. i've played game head handed me. go elsewhere.
# @cashtag @cashtag baltic dry index lower 8 day 30 years... @url
# @cashtag stalled @ 106.44 previously looking enter near $106.50
# @mentions buy alert bellmichael james ent.no buying @cashtag
# @cashtag breakout $29.83 would constitute technical entry short term trader. @url
# @mentions : cook supply chain expert. u think would allow @cashtag shortage deter @cashtag qmark //sorry longs, correction mode $$
# @cashtag back 1.07 hour good news coming i'll hold thirty large make beg like dog buy @ 1.50
# crazy ceo marissa mayer would receive multiple million dollar failing turn @cashtag around. #fresheyes @url
# profit taking @cashtag morning qmark pressure stock. i'm still bullish @cashtag
# @cashtag hit short term target 100 sma. @url expecting retest (of retest gap) then.. even meeting qmark
# rt @mentions next long i'm eyeing @cashtag $27.00.../i'm going one - 400 shares, though
# reason caution chinese stocks. @cashtag @cashtag @cashtag @cashtag @url
# short setup looking nice....really nice | @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag hit high $3.61 emark +12.81% friday's $3.20 buy call emark @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @mentions : @cashtag hell would touch right qmark " <the bought steve job passed away antennagate happened...
# another 3 week tight pattern trigger 61.03 @cashtag @url
# @cashtag downgrade @cashtag good opportunity buy. it, don't sell buy again. taxable event emark @url
# earnings season underway @cashtag slipping 3+% report. today close @cashtag railroad stock others report
# closed buy 1.0 lot @cashtag 15.28 +66.0 pips, total today +66.0 pip @cashtag @cashtag @cashtag visit @url trade
# vivus @cashtag bear raid effect. stock 12%
# @cashtag +1.46% 15.32, picking speed. may 16 call +35% .19: @url next week $16 call .11c: @url
# @cashtag missed big time @cashtag low 2's back nov. 2012, get punked one, 3.61
# excited may take visit. 365 whole food market slated open door may 25 silver lake la. @cashtag
# @cashtag 1m/6m trend turn bullish today resistance level $11.31. @url
# @cashtag full bull call spread ranging july jan 15. let see baby does,
# institution seem like class stocks. 85-90% share @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# nobody want electric car, even cheap on. @cashtag @url
# @cashtag hit high $3.61 emark +12.81% friday's $3.20 buy call emark @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag component supplier @cashtag fall sale.
# @cashtag hod posted buy pm $4.40
# @cashtag @cashtag could lotto winners.
# institution seem like class stocks. 85-90% share @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# @cashtag w/ solid start #ecommerce checkout. @cashtag momentum. @cashtag tbd wwdc. #fintech #digitalwallets @url
# equity index working positive engulfing march. @cashtag @cashtag @cashtag @cashtag @cashtag small-caps semi fakeout b/out.
# @cashtag bot 2.24
# @cashtag - regional bank, clearing new 52-week high good base. relatively thin. @url
# @cashtag china electric car maker. china car sale +7.8%. also, may feed @cashtag momentum run lately. #tesla #trade @url
# scan later, couple notes. rarely intermarket r list 20pt mover, week @cashtag went 26 66
# @cashtag well go..at least know sector white hot next week..huge buy names.. @cashtag @cashtag @cashtag @cashtag ..nice work
# @mentions that. it's er's lol. looking correlation @cashtag foreign price charts, poised breakout.
# @cashtag back highs. @cashtag energy play. @cashtag trying break 5 day range. @cashtag 3.69 long #stocks #investing #tradeideas
# index & industry group track closed friday r line new highs. @cashtag @cashtag @cashtag 50 @cashtag 20 @cashtag @cashtag
# @mentions : large cap tech finally trying catch rest market. @cashtag @cashtag @cashtag
# @cashtag got good news today, @cashtag exercised option take cd19 program outside n.a. & china & pay $50mln fee.
# @cashtag may lower entry point confirm. chart update explains key points. confirmation key.
# @cashtag chart flashing oversold.
# @cashtag long 8.00
# #fintech provider @cashtag cachet financial solution surging forward today post earnings +13.26% @url @cashtag @cashtag #momo
# sto apr @cashtag 109/112 call spread 1.40.
# @cashtag beat estimates. still go lack new products. @url
# @mentions think @cashtag plenty room run lot momentum continue pushing new highs. currently pt $150+
# +.20 @cashtag put @cashtag lookin' ill again. let burn emark looking bottom 2:30ish emark
# @mentions bit disappointed apple watch, expecting bigger updates. otherwise long @cashtag
# good morning emark here's trending among #investors morning. @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag @cashtag
# anyone else see issue this. wonder @cashtag stock suck @url
# @mentions : @cashtag @cashtag green, lol... make-up cover ugliness #ftw @url <-- r yesterday boom today
# #netflix raising price 17m subscriber $2. so: you're paying $7.99 now, you'll paying $9.99 next month. cancel qmark @cashtag
# @cashtag covered last 36.2
# #fedday looking sharp move equity @cashtag @cashtag @cashtag @cashtag seeing @cashtag @cashtag getting hammered, even though market down.
# fear mechanically driving public market lower, record corp. cash & cheap financing fueling wave acquisition @cashtag @cashtag
# nice name watch tomorrow @cashtag long $8+, @cashtag short $1.85-2.00. @cashtag @cashtag @cashtag potential r/g @cashtag short $11. #stocks
# @cashtag wouldn't surprised $33 oil. cheaper oil introduce shipment higher tanker rates.
# @cashtag q1 disappoints #software license down. real problem qmark #cloud growth trail @cashtag @cashtag @cashtag @cashtag @cashtag @url
# @cashtag @cashtag cnbc up'd both... short lololol @mentions @mentions @mentions @mentions @mentions @mentions @mentions
# @mentions best case, 15-20 year @cashtag different @cashtag today -- efficient boring.
# @cashtag update buy point changed 319 318 today.
# seat belt recall qmark cares....i'm buyer @cashtag
# +.20 @cashtag put @cashtag lookin' ill again. let burn emark looking bottom 2:30ish emark
# @cashtag i'm glad got stopped $113 weekly did. re-enter next monday #earnings run-up.
# @cashtag +5.1%
# sold half @cashtag long $2.75 $2.51 entry yesterday noted here: @url moved stop entry price.
# @cashtag 100% upside left next 6 mnths based @cashtag nov 2010 @cashtag 100% based @cashtag july 2007. history rhyme
# @cashtag ..... jan it's sinking ship...
# @cashtag jan-18 6 put big print, 15k $0.18
# 2013 longs(12/31/2012 close) @cashtag >2.89 @cashtag >2.89 @cashtag >8.44 @cashtag >20.99 @cashtag >34.69 @cashtag >51.00 @cashtag >1.30 >>> i'm up( +8.332% ) qmark
# @mentions aren't loading @cashtag qmark future profit huge. surely aren't investing stock based q1
# @cashtag major pump dump coming week. follow money.
# @cashtag still like challenge trade...but i'll wait little longer re-entering.
# @mentions note monthly chart @cashtag & recaptured support. @cashtag possible double bottom set up. @url
# @cashtag short week next week. chart targeting high $92.80. @cashtag $84.65 @cashtag $9.97. still holding 150 @cashtag share 450. sl 79.11
# @mentions sound like @cashtag getting @cashtag treatment - analyst conjuring metric bring boost short positions.
# @cashtag 73.24

# %%
train_df
# Out:
#       sentiment                                            snippet  target  \
# 0        -0.463                                          downgrade   $PCAR
# 1         0.678       [looking sexy this morning, break on volume]   $AMZN
# 2         0.377                               still long term fan!   $SBUX
# 3         0.129  $TFM will have a way to go price wise to compe...     $KR
# 4         0.395      iPhone SE Could Be Doing Better Than Expected   $AAPL
# 5         0.458      Now up to 200 stocks making new 52 week highs    $TJX
# 6         0.288  There's no reason why $GOOGL can't get back to...  $GOOGL
# 7        -0.453                                              short   $CVEO
# 8         0.372               Pivotal sees 27% upside for Alphabet   $YHOO
# 9         0.216                                  the most trending   $DWTI
# 10        0.241  $GOOGL patents turn signal detector for autono...  $GOOGL
# 11        0.557            Investor long-term stock recommendation   $COST
# 12        0.419      Breaking 52 week highs timing looks great now   $IRDM
# 13       -0.641    makes less profit than the sales of $AAPL Watch     $FB
# 14        0.344                      I'm watching(and buy targets)    $CSX
# 15       -0.289  decision to sell robot business exposes growin...  $GOOGL
# 16        0.430                    [$MSFT, higher than I expected]   $MSFT
# 17       -0.147                                 suddenly realizing     $FB
# 18        0.484  [10% Dividend Increase Rewards Patient Investo...   $QCOM
# 19        0.529                                    Nice day rally!    $SLB
# 20        0.406                                          #oversold   $CLDX
# 21       -0.317                                     Today's losers   $ENDP
# 22        0.374                                next major platform   $AMZN
# 23        0.589                                 Added $REGN at 402   $REGN
# 24       -0.195                     It Needs A New Tablet Strategy   $AAPL
# 25       -0.591                                          sell $RHT    $RHT
# 26        0.422             I'll take the other side of that trade    $AGN
# 27       -0.374                                 getting out of his   $TSLA
# 28        0.489                                          buy $WYNN   $WYNN
# 29       -0.140  less than stellar day but it held the 50 day m...   $COST
# ...         ...                                                ...     ...
# 1366      0.194              buy point has changed to 319 from 318   $AMZN
# 1367      0.598                                        I'm a buyer   $TSLA
# 1368      0.314                   Stocks Higher In Afternoon Trade     $UA
# 1369     -0.382                                         Lets BURN!   $AAPL
# 1370     -0.039                     Now I'm glad I got stopped out   $AAPL
# 1371     -0.259                                    all out for now   $QLYS
# 1372      0.329                                       Covered Call   $SCTY
# 1373      0.259                  I sold half of my $UGAZ Long here   $UGAZ
# 1374      0.222    over 100% upside left from here in next 6 mnths   $BIDU
# 1375     -0.573                           it's been a sinking ship     $HK
# 1376     -0.451                      Jan-18 6 Put with a big print   $SYMC
# 1377      0.511                                              LONGS   $CLWR
# 1378      0.294                        Future profits will be huge   $YELP
# 1379     -0.133               Major pump and dump coming this week    $OCN
# 1380      0.452                               biggest St50 gainers    $PKT
# 1381      0.168            wait a little longer before re-entering   $UGAZ
# 1382      0.272                      possible double bottom set up    $GLD
# 1383     -0.134                               Short week next week    $TZA
# 1384      0.419      Breaking 52 week highs timing looks great now    $IGE
# 1385      0.219  Short Squeeze Ready To Upside w Crossing Impor...    $MGM
# 1386      0.529                                       buy area now   $AAPL
# 1387     -0.302                         Begin The Assault On Intel   $INTC
# 1388      0.087                                Today I bought more   $YHOO
# 1389     -0.312  analysts conjuring up metrics to bring it down...   $AAPL
# 1390      0.395                                     Surges On Deal  $CMCSA
# 1391      0.489                   If i had to pick one it would be    $STX
# 1392      0.314                   Stocks Higher In Afternoon Trade     $AA
# 1393     -0.189  Not sure we can see too much $TSLA up side thu...   $TSLA
# 1394     -0.287                  NO one Believes in Flyin' anymore   $PCLN
# 1395      0.322                                           In 73.24    $TNA
#
#                                                   tweet
# 0     downgrade @cashtag @cashtag @cashtag @cashtag ...
# 1     @cashtag looking sexy morning...$600 break vol...
# 2     @mentions stock hasn't moved much since first ...
# 3     whole food @cashtag may feel price competition...
# 4     apple's iphone se could better expected via @m...
# 5     200 stock making new 52 week high (big number)...
# 6     there's reason @cashtag can't get back $1,000 ...
# 7     nice name watch tomorrow @cashtag long $8+, @c...
# 8     pivotal see 27% upside alphabet @url @cashtag ...
# 9     good morning emark here's trending among #inve...
# 10    @cashtag patent turn signal detector autonomou...
# 11    sftw investor long-term stock recommendation: ...
# 12    breaking 52 week high timing look great @casht...
# 13    amazing @cashtag 300b market cap make le profi...
# 14    stock i'm watching(and buy targets): @cashtag ...
# 15    google's decision sell robot business expose g...
# 16    @cashtag @cashtag higher expected, @cashtag mu...
# 17    facebook suddenly realizing snr problem newsfe...
# 18    qualcomm: 10% dividend increase reward patient...
# 19    @cashtag @cashtag @cashtag @cashtag @cashtag @...
# 20    looking sale curious @cashtag drop among #over...
# 21    today's losers: @cashtag @cashtag @cashtag @ca...
# 22    don't look #amazon & ; #bezos done again. quie...
# 23                                   added @cashtag 402
# 24    apple need new tablet, need new tablet strateg...
# 25    #fastmoneyespresso final trades: pete najarian...
# 26    @mentions anyone selling/shorting @cashtag b/c...
# 27          @mentions #tomsosnoff getting @cashtag @url
# 28    #fastmoneyespresso final trades: pete najarian...
# 29    @cashtag costco le stellar day held 50 day mov...
# ...                                                 ...
# 1366   @cashtag update buy point changed 319 318 today.
# 1367  seat belt recall qmark cares....i'm buyer @cas...
# 1368  stock higher afternoon trade; intel nears buy ...
# 1369  +.20 @cashtag put @cashtag lookin' ill again. ...
# 1370  @cashtag i'm glad got stopped $113 weekly did....
# 1371                                     @cashtag +5.1%
# 1372  covered call alert @cashtag @cashtag @cashtag ...
# 1373  sold half @cashtag long $2.75 $2.51 entry yest...
# 1374  @cashtag 100% upside left next 6 mnths based @...
# 1375            @cashtag ..... jan it's sinking ship...
# 1376         @cashtag jan-18 6 put big print, 15k $0.18
# 1377  2013 longs(12/31/2012 close) @cashtag >2.89 @c...
# 1378  @mentions aren't loading @cashtag qmark future...
# 1379  @cashtag major pump dump coming week. follow m...
# 1380  rt @mentions mostly red tape morning, biggest ...
# 1381  @cashtag still like challenge trade...but i'll...
# 1382  @mentions note monthly chart @cashtag & recapt...
# 1383  @cashtag short week next week. chart targeting...
# 1384  breaking 52 week high timing look great @casht...
# 1385  @cashtag jetblue short squeeze ready upside w ...
# 1386  @cashtag @url clearing descending trend line b...
# 1387  google, ibm, arm amd begin assault intel's ser...
# 1388  today bought @cashtag @cashtag @cashtag @casht...
# 1389  @mentions sound like @cashtag getting @cashtag...
# 1390  tv remote control maker surge deal comcast @ur...
# 1391                    chanos: pick one would @cashtag
# 1392  stock higher afternoon trade; intel nears buy ...
# 1393    @mentions sure see much @cashtag side thus week
# 1394  @cashtag memories: one belief flyin' anymore :...
# 1395                                     @cashtag 73.24
#
# [1396 rows x 4 columns]

# %% [markdown]
# # Training the Model (Linear Regression)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer( analyzer='word',
                      ngram_range=(1,3),
                      stop_words = 'english')

# %%
model = cv.fit_transform(list(train_df["tweet"]))

# %% [markdown]
# X = list(train_df["tweet"])
# y = train_df["sentiment"]
# X = cv.fit_transform(X)
# X_train, X_test, y_train, y_test = train_test_split(X , y, test_size=0.33, random_state=42 )

# %%
cv.fit(train_df["tweet"])
X_train = cv.transform(train_df["tweet"])
X_test = cv.transform(test_df["tweet"])
y_train = train_df["sentiment"]
y_test = test_df["sentiment"]

# %%
#linear regression model
from sklearn.linear_model import LinearRegression
log_model = LinearRegression(fit_intercept=True)
log_model = log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)

# %% [markdown]
# # Evaluation

# %%
def assignClasses(data): 
    value = list()
    for i in data: 
        if i > 0:
            value.append("bullish")
        elif i < 0:
            value.append("bearish")
        else:
            value.append("neutral")
    
    return value

# %%
n_y_test = assignClasses(y_test)
n_y_pred = assignClasses(y_pred)

# %%
#from sklearn.metrics import mean_squared_error
#from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

print("MSE: ", mean_squared_error(y_test, y_pred))
print('\n')
print("F1 Macro Avg: ", f1_score(n_y_test, n_y_pred, average='macro'))
print("F1 Micro Avg: ", f1_score(n_y_test, n_y_pred, average='micro'))
print('\n')
print("Classification Report  \n", classification_report(n_y_test, n_y_pred))
# Out:
# MSE:  0.0925858930359
#
#
# F1 Macro Avg:  0.511043613707
# F1 Micro Avg:  0.788643533123
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#     bearish       0.77      0.62      0.68       221
#     bullish       0.80      0.91      0.85       401
#     neutral       0.00      0.00      0.00        12
#
# avg / total       0.77      0.79      0.78       634
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
