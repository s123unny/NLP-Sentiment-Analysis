# %%
# Import the necessary modules
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split 
import pandas as pd

from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error

import numpy as np

import matplotlib.pyplot as plt
from matplotlib import style

# Adjusting the size of matplotlib
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__

# Adjusting the style of matplotlib
style.use('ggplot')

# Magic to tell python notebook we want matplotlib charts included
# %matplotlib inline

# %%
train_df = pd.read_json("training_set.json")
test_df = pd.read_json("test_set.json")
# hashtag_corpus = pd.read_json("NTUSDFinCorpus/NTUSD_Fin_hashtag_v1.0.json")
# word_corpus = pd.read_json("NTUSDFinCorpus/NTUSD_Fin_word_v1.0.json")

# %% [markdown]
# conditions = [
#     (train_df['sentiment'] == 0) ,
#     (train_df['sentiment'] <  0) ,
#     (train_df['sentiment'] >  0)]
# choices = ['neutral', 'bullish', 'bearish']
# train_df['classes'] = np.select(conditions, choices, default='neutral')

# %% [markdown]
# # Pre-Processing

# %%
train_df['tweet'] = train_df['tweet'].str.lower()
train_df['tweet'] = train_df['tweet'].str.replace('([@][\w_-]+)', ' @mentions ', case=False)
train_df['tweet'] = train_df['tweet'].str.replace('([$][a-z]+)', ' @cashtag ', case=False)
train_df['tweet'] = train_df['tweet'].str.replace('http\S+|www.\S+', '@url', case=False)

# %%
test_df['tweet'] = test_df['tweet'].str.lower()
test_df['tweet'] = test_df['tweet'].str.replace('([@][\w_-]+)', ' @mentions ', case=False)
test_df['tweet'] = test_df['tweet'].str.replace('([$][a-z]+)', ' @cashtag ', case=False)
test_df['tweet'] = test_df['tweet'].str.replace('http\S+|www.\S+', '@url', case=False)

# %%
test_df
# Out:
#      sentiment                                            snippet target  \
# 0        0.323                        ooks pretty bullish for now  $ATVI
# 1        0.579  [looks really interesting on drop, grabbed som...  $CSCO
# 2        0.294                                covered some shorts  $TSLA
# 3        0.028                                triple top forming.  $TSLA
# 4       -0.076  Whole Foods shareholders vote down activist in...   $WFM
# 5       -0.387                       Still too early for an entry    $FB
# 6        0.087                                Today I bought more   $AXP
# 7       -0.464           Short Setups Looking Nice....Really Nice   $BBY
# 8       -0.291              Tesla is recalling 2,700 Model X cars  $TSLA
# 9        0.318                              What a nice reversal.  $GOOG
# 10      -0.618                                  Short $TSLA calls  $TSLA
# 11       0.448             [Breakout Should be Confirmed, Upturn]  $CTRP
# 12       0.376                                    Best performers  $AAPL
# 13      -0.406         very tight on the avail stock for shorting  $VALE
# 14       0.415                             get into $WFM and $MJN   $WFM
# 15       0.419                              working on Cuba deals   $HOT
# 16       0.322                           First quarter is amazing   $RIG
# 17       0.454                        Sector Stocks Leading Today   $HAR
# 18       0.241            Will A Onetime Zombie Stock Rise Again?  $AKAM
# 19       0.344                      I'm watching(and buy targets)   $LVS
# 20      -0.643             after losing about $1 billion on $VRX?   $VRX
# 21       0.562  The Top 10 brands for #millennials - $AAPL is ...  $AAPL
# 22       0.310                                      looking tasty   $WDC
# 23       0.271                     Markets Back in Black for 2016   $SDS
# 24       0.529                                    Nice day rally!   $QQQ
# 25       0.348                          Highest call to put ratio  $GALE
# 26       0.366  beats the Estimize EPS Consensus by 6c and the...  $CTRP
# 27       0.328                [slight green, May be runner later]    $FB
# 28       0.225   $MSFT is opening up its #XboxLive online service  $MSFT
# 29       0.268                                       here we gooo  $NFLX
# ..         ...                                                ...    ...
# 604     -0.420  With Oil Prices Down further, Oil Stocks Looki...   $GST
# 605      0.259                                    Finding Support   $ERO
# 606      0.448              Found some good bull setups this week   $XRS
# 607      0.000                                                      $OCN
# 608     -0.370            [wants lower, up waves getting smaller]  $AAPL
# 609      0.597  [great growth stk & also raised dividend, clea...  $AVGO
# 610     -0.524                      trying to drag $bidu with it.  $SINA
# 611     -0.315                          60% short interest or not  $FRPT
# 612     -0.351         The momo leaders are taken down one by one  $PCYC
# 613     -0.385                              Stochastic Overbought  $FREE
# 614      0.415  [While we think $TNH is a winner, we are ringi...   $TNH
# 615     -0.339                                  new squeeze plays   $XRS
# 616     -0.490                                        Active puts   $MGM
# 617     -0.559                                     all going down  $RIMM
# 618     -0.419  [Failed breakouts & failed setups, Limping on ...  $INVN
# 619      0.433                     stocks insiders are bullish on   $HON
# 620     -0.002                                      Drop expected  $UGAZ
# 621      0.715         Upgraded to a buy by Alpha Street Research  $CRUS
# 622      0.145                                Worth a chance here   $SLW
# 623      0.219                              expects to break even  $BLDP
# 624     -0.319                                alot to worry about   $SPY
# 625      0.608                        huge buy in all these names     $X
# 626     -0.131                                       so volatile!  $UVXY
# 627     -0.287  [Could the pride of social media be gettin rea...   $SPY
# 628      0.442  [gold going parabolic, keep chasing those tops...  $FEYE
# 629      0.543  [hold through all the media BS and you will be...   $CTB
# 630     -0.391  I Love blood like a vampire.....Keep bleeding ...  $NFLX
# 631      0.262                         airplanes are still flying   $DAL
# 632      0.423                                       $IEF bullish   $IEF
# 633     -0.264  best scenario going forward is this stock slow...  $TWTR
#
#                                                  tweet
# 0     @cashtag  ooks pretty bullish for now. from a...
# 1     @cashtag  looks really interesting on drop, g...
# 2     @cashtag  : covered some shorts @ 246.00 for ...
# 3            watching  @cashtag  w triple top forming.
# 4    whole foods shareholders vote down activist in...
# 5     @cashtag  has returned to my short watchlist....
# 6    today i bought more  @cashtag   @cashtag   @ca...
# 7    short setups looking nice....really nice |  @c...
# 8    tesla is recalling 2,700 model x cars: @url  @...
# 9    thank you  @cashtag  (google alphabet) and  @c...
# 10                              short  @cashtag  calls
# 11    @cashtag  @url $46 breakout should be confirm...
# 12   dow worst performers chevron -0.47 and nike -0...
# 13    @cashtag  borrow still -7.5% which means very...
# 14    @mentions   @mentions   @mentions  guys - get...
# 15    @cashtag   @cashtag   @cashtag  working on cu...
# 16   . @mentions     @cashtag   @cashtag   @cashtag...
# 17   sector stocks leading today:  @cashtag   @cash...
# 18   akamai: will a onetime zombie stock rise again...
# 19   stocks i'm watching(and buy targets):  @cashta...
# 20   marketwatch: rt wmwitkowski: guess who sold of...
# 21   the top 10 brands for #millennials -  @cashtag...
# 22             @cashtag  looking tasty...  and #twerky
# 23   markets back in black for 2016  @cashtag   @ca...
# 24    @cashtag   @cashtag   @cashtag   @cashtag   @...
# 25   highest call to put ratio  @cashtag   @cashtag...
# 26    @cashtag  beats the estimize eps consensus by...
# 27       @cashtag  slight green... may be runner later
# 28    @cashtag  is opening up its #xboxlive online ...
# 29    @cashtag  100$ here we gooo\nour target 103$ ...
# ..                                                 ...
# 604  with oil prices down further, oil stocks looki...
# 605  eur/usd finding support near 1.10 level  @cash...
# 606  found some good bull setups this week:  @casht...
# 607    @cashtag  huge blocks now 11,500  @mentions .92
# 608   @cashtag  wants lower. up waves getting small...
# 609   @cashtag  great growth stk &amp;  also raised...
# 610       @cashtag  trying to drag  @cashtag  with it.
# 611   @cashtag  this could be in teens again in one...
# 612  the momo leaders are taken down one by one. lo...
# 613  end of day scan: stochastic overbought  @casht...
# 614  while we think  @cashtag  is a winner, we are ...
# 615  new squeeze plays #stocks @url  @cashtag   @ca...
# 616  active puts @ cboe;  @cashtag  9/27/13 480  @c...
# 617   @cashtag   @cashtag   @cashtag   @cashtag   @...
# 618  failed breakouts &amp; failed setups.  limping...
# 619  11 industrial-goods stocks insiders are bullis...
# 620   @cashtag  : drop expected as london traders w...
# 621   @cashtag  upgraded to a buy by alpha street r...
# 622   @cashtag  is down, but weekly $34 calls (-28....
# 623   @cashtag  expects to break even for the first...
# 624   @mentions  4 more years will be alot to worry...
# 625   @cashtag  well here you go..at least you know...
# 626                    @cashtag  so volatile! yowza :p
# 627   @cashtag  could the pride of social media be ...
# 628   @cashtag  gold going parabolic... wonder why?...
# 629   @cashtag  hold through all the media bs and y...
# 630   @cashtag  i love blood like a vampire.....kee...
# 631   @mentions   @mentions  yea dude, airplanes ar...
# 632  ten year yield, weekly @url 10 year yield stil...
# 633   @cashtag  the best scenario going forward is ...
#
# [634 rows x 4 columns]

# %%
train_df
# Out:
#       sentiment                                            snippet  target  \
# 0        -0.463                                          downgrade   $PCAR
# 1         0.678       [looking sexy this morning, break on volume]   $AMZN
# 2         0.377                               still long term fan!   $SBUX
# 3         0.129  $TFM will have a way to go price wise to compe...     $KR
# 4         0.395      iPhone SE Could Be Doing Better Than Expected   $AAPL
# 5         0.458      Now up to 200 stocks making new 52 week highs    $TJX
# 6         0.288  There's no reason why $GOOGL can't get back to...  $GOOGL
# 7        -0.453                                              short   $CVEO
# 8         0.372               Pivotal sees 27% upside for Alphabet   $YHOO
# 9         0.216                                  the most trending   $DWTI
# 10        0.241  $GOOGL patents turn signal detector for autono...  $GOOGL
# 11        0.557            Investor long-term stock recommendation   $COST
# 12        0.419      Breaking 52 week highs timing looks great now   $IRDM
# 13       -0.641    makes less profit than the sales of $AAPL Watch     $FB
# 14        0.344                      I'm watching(and buy targets)    $CSX
# 15       -0.289  decision to sell robot business exposes growin...  $GOOGL
# 16        0.430                    [$MSFT, higher than I expected]   $MSFT
# 17       -0.147                                 suddenly realizing     $FB
# 18        0.484  [10% Dividend Increase Rewards Patient Investo...   $QCOM
# 19        0.529                                    Nice day rally!    $SLB
# 20        0.406                                          #oversold   $CLDX
# 21       -0.317                                     Today's losers   $ENDP
# 22        0.374                                next major platform   $AMZN
# 23        0.589                                 Added $REGN at 402   $REGN
# 24       -0.195                     It Needs A New Tablet Strategy   $AAPL
# 25       -0.591                                          sell $RHT    $RHT
# 26        0.422             I'll take the other side of that trade    $AGN
# 27       -0.374                                 getting out of his   $TSLA
# 28        0.489                                          buy $WYNN   $WYNN
# 29       -0.140  less than stellar day but it held the 50 day m...   $COST
# ...         ...                                                ...     ...
# 1366      0.194              buy point has changed to 319 from 318   $AMZN
# 1367      0.598                                        I'm a buyer   $TSLA
# 1368      0.314                   Stocks Higher In Afternoon Trade     $UA
# 1369     -0.382                                         Lets BURN!   $AAPL
# 1370     -0.039                     Now I'm glad I got stopped out   $AAPL
# 1371     -0.259                                    all out for now   $QLYS
# 1372      0.329                                       Covered Call   $SCTY
# 1373      0.259                  I sold half of my $UGAZ Long here   $UGAZ
# 1374      0.222    over 100% upside left from here in next 6 mnths   $BIDU
# 1375     -0.573                           it's been a sinking ship     $HK
# 1376     -0.451                      Jan-18 6 Put with a big print   $SYMC
# 1377      0.511                                              LONGS   $CLWR
# 1378      0.294                        Future profits will be huge   $YELP
# 1379     -0.133               Major pump and dump coming this week    $OCN
# 1380      0.452                               biggest St50 gainers    $PKT
# 1381      0.168            wait a little longer before re-entering   $UGAZ
# 1382      0.272                      possible double bottom set up    $GLD
# 1383     -0.134                               Short week next week    $TZA
# 1384      0.419      Breaking 52 week highs timing looks great now    $IGE
# 1385      0.219  Short Squeeze Ready To Upside w Crossing Impor...    $MGM
# 1386      0.529                                       buy area now   $AAPL
# 1387     -0.302                         Begin The Assault On Intel   $INTC
# 1388      0.087                                Today I bought more   $YHOO
# 1389     -0.312  analysts conjuring up metrics to bring it down...   $AAPL
# 1390      0.395                                     Surges On Deal  $CMCSA
# 1391      0.489                   If i had to pick one it would be    $STX
# 1392      0.314                   Stocks Higher In Afternoon Trade     $AA
# 1393     -0.189  Not sure we can see too much $TSLA up side thu...   $TSLA
# 1394     -0.287                  NO one Believes in Flyin' anymore   $PCLN
# 1395      0.322                                           In 73.24    $TNA
#
#                                                   tweet
# 0     downgrades  @cashtag   @cashtag   @cashtag   @...
# 1      @cashtag  looking sexy this morning...$600 br...
# 2      @mentions  stock hasn't moved much since firs...
# 3     whole foods  @cashtag  may feel price competit...
# 4     apple's iphone se could be doing better than e...
# 5     now up to 200 stocks making new 52 week highs ...
# 6     there's no reason why  @cashtag  can't get bac...
# 7     nice names on watch for tomorrow  @cashtag  lo...
# 8     pivotal sees 27% upside for alphabet @url  @ca...
# 9     good morning! here's some of the most trending...
# 10     @cashtag  patents turn signal detector for au...
# 11    sftw investor long-term stock recommendation: ...
# 12    breaking 52 week highs timing looks great now\...
# 13    amazing how  @cashtag  at 300b market cap make...
# 14    stocks i'm watching(and buy targets):  @cashta...
# 15    google's decision to sell robot business expos...
# 16     @cashtag   @cashtag  higher than i expected, ...
# 17    facebook is suddenly realizing snr is a proble...
# 18    qualcomm: 10% dividend increase rewards patien...
# 19     @cashtag   @cashtag   @cashtag   @cashtag   @...
# 20    looking for sales curious about  @cashtag  dro...
# 21    today's losers:  @cashtag   @cashtag   @cashta...
# 22    don't look now but #amazon &amp; #bezos have d...
# 23                              added  @cashtag  at 402
# 24    apple does not need a new tablet, it needs a n...
# 25    #fastmoneyespresso\nfinal trades:\npete  najar...
# 26     @mentions  if anyone is selling/shorting  @ca...
# 27     @mentions  #tomsosnoff getting out of his  @c...
# 28    #fastmoneyespresso\nfinal trades:\npete  najar...
# 29     @cashtag  costco less than stellar day but it...
# ...                                                 ...
# 1366   @cashtag   update the buy point has changed t...
# 1367  seat belt recall? who cares....i'm a buyer  @c...
# 1368  stocks higher in afternoon trade; intel nears ...
# 1369  +.20 in my  @cashtag  puts  @cashtag  lookin' ...
# 1370   @cashtag  now i'm glad i got stopped out of m...
# 1371                    @cashtag  all out for now +5.1%
# 1372  covered call alerts for  @cashtag ,  @cashtag ...
# 1373  i sold half of my  @cashtag  long here at $2.7...
# 1374   @cashtag  over 100% upside left from here in ...
# 1375  what is up with  @cashtag ..... from jan to no...
# 1376   @cashtag  jan-18 6 put with a big print, 15k ...
# 1377  2013 longs(12/31/2012 close)  @cashtag  >2.89 ...
# 1378   @mentions  why aren't you loading up on  @cas...
# 1379   @cashtag  major pump and dump coming this wee...
# 1380  rt  @mentions  in a mostly red tape this morni...
# 1381   @cashtag  still like the challenge of this tr...
# 1382   @mentions   note the monthly chart of  @casht...
# 1383   @cashtag  short week next week.  charts targe...
# 1384  breaking 52 week highs timing looks great now ...
# 1385   @cashtag  jetblue short squeeze ready to upsi...
# 1386   @cashtag  @url clearing this descending trend...
# 1387  google, ibm, arm and amd begin the assault on ...
# 1388  today i bought more  @cashtag   @cashtag   @ca...
# 1389   @mentions  sounds like  @cashtag  is getting ...
# 1390  tv remote control maker surges on deal with co...
# 1391  chanos: if i had to pick one it would be  @cas...
# 1392  stocks higher in afternoon trade; intel nears ...
# 1393   @mentions  not sure we can see too much  @cas...
# 1394   @cashtag  memories: no one believes in flyin'...
# 1395                                 @cashtag  in 73.24
#
# [1396 rows x 4 columns]

# %% [markdown]
# # Training the Model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer( analyzer='word',
                      ngram_range=(1,3),
                      stop_words = 'english')

# %%
model = cv.fit_transform(list(train_df["tweet"]))

# %% [markdown]
# X = list(train_df["tweet"])
# y = train_df["sentiment"]
# X = cv.fit_transform(X)
# X_train, X_test, y_train, y_test = train_test_split(X , y, test_size=0.33, random_state=42 )

# %%
cv.fit(train_df["tweet"])
X_train = cv.transform(train_df["tweet"])
X_test = cv.transform(test_df["tweet"])
y_train = train_df["sentiment"]
y_test = test_df["sentiment"]

# %%
#linear regression model
from sklearn.linear_model import LinearRegression
log_model = LinearRegression(fit_intercept=True)
log_model = log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)

# %% [markdown]
# #random forest
# from sklearn.ensemble import RandomForestClassifier
#
# clf = RandomForestClassifier(max_depth=2, random_state=0)
# clf.fit(X_train, y_train)
#
# print(clf.feature_importances_)
# forest_prediction = clf.predict(X_test)
# print(forest_prediction)
# print(mean_squared_error(y_test, forest_prediction))

# %% [markdown]
# predictions = nb.predict(X_test)
#
# from sklearn.metrics import confusion_matrix, classification_report
#
# print(confusion_matrix(y_test,predictions))
# print('\n')
# print(classification_report(y_test, predictions))

# %% [markdown]
# # Evaluation

# %%
def assignClasses(data): 
    value = list()
    for i in data: 
        if i > 0:
            value.append("bullish")
        elif i < 0:
            value.append("bearish")
        else:
            value.append("neutral")
    
    return value

# %%
n_y_test = assignClasses(y_test)
n_y_pred = assignClasses(y_pred)

# %%
len(n_y_test)
# Out:
# 634

# %%
#from sklearn.metrics import mean_squared_error
#from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

print("MSE: ", mean_squared_error(y_test, y_pred))
print('\n')
print("F1 Macro Avg: ", f1_score(n_y_test, n_y_pred, average='macro'))
print("F1 Micro Avg: ", f1_score(n_y_test, n_y_pred, average='micro'))
# Out:
# MSE:  0.093756820038
#
#
# F1 Macro Avg:  0.51849022167
# F1 Micro Avg:  0.796529968454
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
